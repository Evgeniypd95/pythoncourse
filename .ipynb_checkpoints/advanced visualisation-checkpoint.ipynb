# %%
import pandas as pd
import os

# %%
movies = pd.read_csv('/Users/evgenypavlov/Public/Python_projects/Python course/P4-Movie-Ratings.csv')

# %%
len(movies)
# Out:
# 559

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies['Film']
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
movies.Film = movies.Film.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 47.4+ KB

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
j = sns.jointplot(data=movies, x='CriticRating', y='BudgetMillions', kind='hex')
# how to visualise ratings per film?

# %%
sns.set_style("darkgrid")
m1 = sns.distplot(movies.AudienceRating)

# %%
# filtering 

movies = movies[movies.Genre == 'Drama']
plt.hist(movies.BudgetMillions)
plt.show()

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating)

# %%
z = sns.violinplot(data=movies, x="Genre", y="CriticRating")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-4cafa3e34d0e> in <module>
# ----> 1 z = sns.violinplot(data=movies, x="Genre", y="CriticRating")
#
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2391                              bw, cut, scale, scale_hue, gridsize,
#    2392                              width, inner, split, dodge, orient, linewidth,
# -> 2393                              color, palette, saturation)
#    2394
#    2395     if ax is None:
#
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation)
#     558
#     559         self.establish_variables(x, y, hue, data, orient, order, hue_order)
# --> 560         self.establish_colors(color, palette, saturation)
#     561         self.estimate_densities(bw, cut, scale, scale_hue, gridsize)
#     562
#
# /Applications/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in establish_colors(self, color, palette, saturation)
#     314         # Determine the gray color to use for the lines framing the plot
#     315         light_vals = [colorsys.rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 316         lum = min(light_vals) * .6
#     317         gray = mpl.colors.rgb2hex((lum, lum, lum))
#     318
#
# ValueError: min() arg is an empty sequence
