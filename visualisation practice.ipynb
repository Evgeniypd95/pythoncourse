# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

plt.rcParams['figure.figsize'] = 20,10
plt.rc('xtick', labelsize=7) 
plt.rc('ytick', labelsize=15)

# %%
df = pd.read_csv('/Users/evgenypavlov/Public/Python_projects/Python course/Facebook engagement January - Sheet1.csv')

# %%
df.head()
# Out:
#          date               id                                      link  \
# 0  2020-01-01  161748600553552  https://www.facebook.com/161748600553552
# 1  2020-01-02  161748600553552  https://www.facebook.com/161748600553552
# 2  2020-01-03  161748600553552  https://www.facebook.com/161748600553552
# 3  2020-01-04  161748600553552  https://www.facebook.com/161748600553552
# 4  2020-01-05  161748600553552  https://www.facebook.com/161748600553552
#
#                      name          page_id               page_name  \
# 0  Colgate UK and Ireland  161748600553552  Colgate UK and Ireland
# 1  Colgate UK and Ireland  161748600553552  Colgate UK and Ireland
# 2  Colgate UK and Ireland  161748600553552  Colgate UK and Ireland
# 3  Colgate UK and Ireland  161748600553552  Colgate UK and Ireland
# 4  Colgate UK and Ireland  161748600553552  Colgate UK and Ireland
#
#     timestamp  actions_post_reactions_anger_total  \
# 0  2020-01-02                                   0
# ...

# %%
df.fans.describe()
# Out:
# count        31.000000
# mean     234488.870968
# std         111.040155
# min      234308.000000
# 25%      234402.500000
# 50%      234486.000000
# 75%      234579.000000
# max      234672.000000
# Name: fans, dtype: float64

# %%
sns.set_style("darkgrid")
vis1 = sns.distplot(df.fans)

# %%
vis2 = sns.lmplot(data=df, x="timestamp", y="fans", fit_reg=False)

# %%
plt.plot(df.date, df.fans)
plt.figure(figsize=(3,4))

# %%
fig = plt.figure()
fig.subplots_adjust(top=0.8)
ax1 = fig.add_subplot(211)
ax1.set_ylabel('fans')
ax1.set_title('date')
plt.plot(df.date, df.fans)
# plt.figure(figsize=(300,400))

# %%
f, axes = plt.subplots(2,2, figsize=(15,15))


plt.subplot(211)
plt.plot(df.date, df.fans)
plt.subplot(212)
plt.plot(df.date, df.post_impressions)

plt.show()
